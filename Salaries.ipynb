# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
sns.set()

# %%
raw_data = pd.read_csv('ds_salaries.csv')
raw_data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0       80000             EUR          85847                 ES           100
# 1       30000             USD          30000                 US           100
# 2       25500             USD          25500                 US           100
# 3      175000             USD         175000                 CA           100
# 4      120000             USD         120000                 CA           100
# ...       ...             ...            ...                ...           ...
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# 0                  ES            L
# 1                  US            S
# 2                  US            S
# 3                  CA            M
# 4                  CA            M
# ...               ...          ...
# 3750               US            L
# 3751               US            L
# 3752               US            S
# 3753               US            L
# 3754               IN            L
#
# [3755 rows x 11 columns]

# %%
raw_data.describe(include='all')
# Out:
#           work_year experience_level employment_type      job_title  \
# count   3755.000000             3755            3755           3755
# unique          NaN                4               4             93
# top             NaN               SE              FT  Data Engineer
# freq            NaN             2516            3718           1040
# mean    2022.373635              NaN             NaN            NaN
# std        0.691448              NaN             NaN            NaN
# min     2020.000000              NaN             NaN            NaN
# 25%     2022.000000              NaN             NaN            NaN
# 50%     2022.000000              NaN             NaN            NaN
# 75%     2023.000000              NaN             NaN            NaN
# max     2023.000000              NaN             NaN            NaN
#
#               salary salary_currency  salary_in_usd employee_residence  \
# count   3.755000e+03            3755    3755.000000               3755
# unique           NaN              20            NaN                 78
# top              NaN             USD            NaN                 US
# freq             NaN            3224            NaN               3004
# mean    1.906956e+05             NaN  137570.389880                NaN
# std     6.716765e+05             NaN   63055.625278                NaN
# min     6.000000e+03             NaN    5132.000000                NaN
# 25%     1.000000e+05             NaN   95000.000000                NaN
# 50%     1.380000e+05             NaN  135000.000000                NaN
# 75%     1.800000e+05             NaN  175000.000000                NaN
# max     3.040000e+07             NaN  450000.000000                NaN
#
#         remote_ratio company_location company_size
# count    3755.000000             3755         3755
# unique           NaN               72            3
# top              NaN               US            M
# freq             NaN             3040         3153
# mean       46.271638              NaN          NaN
# std        48.589050              NaN          NaN
# min         0.000000              NaN          NaN
# 25%         0.000000              NaN          NaN
# 50%         0.000000              NaN          NaN
# 75%       100.000000              NaN          NaN
# max       100.000000              NaN          NaN

# %%
raw_data = raw_data.drop(['salary', 'salary_currency'], axis=1)
raw_data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# 0             85847                 ES           100               ES
# 1             30000                 US           100               US
# 2             25500                 US           100               US
# 3            175000                 CA           100               CA
# 4            120000                 CA           100               CA
# ...             ...                ...           ...              ...
# 3750         412000                 US           100               US
# 3751         151000                 US           100               US
# 3752         105000                 US           100               US
# 3753         100000                 US           100               US
# 3754          94665                 IN            50               IN
#
#      company_size
# 0               L
# 1               S
# 2               S
# 3               M
# 4               M
# ...           ...
# 3750            L
# 3751            L
# 3752            S
# 3753            L
# 3754            L
#
# [3755 rows x 9 columns]

# %%
raw_data.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
data_no_mv = raw_data.dropna(axis=0)

# %%
sns.distplot(data_no_mv['salary_in_usd'])
# Out:
# <ipython-input-7-9330910ebd6f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_mv['salary_in_usd'])
# <Axes: xlabel='salary_in_usd', ylabel='Density'>

# %%
data_no_mv['log_salary'] = np.log(data_no_mv['salary_in_usd'])

# %%
q = data_no_mv['salary_in_usd'].quantile(0.99)
# Then we can create a new df, with the condition that all prices must be below the 99 percentile of 'Price'
data_1 = data_no_mv[data_no_mv['salary_in_usd']<q]
# In this way we have essentially removed the top 1% of the data about 'Price'
data_1.describe(include='all')
# Out:
#           work_year experience_level employment_type      job_title  \
# count   3716.000000             3716            3716           3716
# unique          NaN                4               4             92
# top             NaN               SE              FT  Data Engineer
# freq            NaN             2493            3680           1031
# mean    2022.373520              NaN             NaN            NaN
# std        0.688993              NaN             NaN            NaN
# min     2020.000000              NaN             NaN            NaN
# 25%     2022.000000              NaN             NaN            NaN
# 50%     2022.000000              NaN             NaN            NaN
# 75%     2023.000000              NaN             NaN            NaN
# max     2023.000000              NaN             NaN            NaN
#
#         salary_in_usd employee_residence  remote_ratio company_location  \
# count     3716.000000               3716   3716.000000             3716
# unique            NaN                 77           NaN               72
# top               NaN                 US           NaN               US
# freq              NaN               2967           NaN             3003
# mean    135330.369483                NaN     46.219053              NaN
# std      59301.774055                NaN     48.585310              NaN
# min       5132.000000                NaN      0.000000              NaN
# 25%      95000.000000                NaN      0.000000              NaN
# 50%     134368.000000                NaN      0.000000              NaN
# 75%     175000.000000                NaN    100.000000              NaN
# max     304000.000000                NaN    100.000000              NaN
#
#        company_size   log_salary
# count          3716  3716.000000
# unique            3          NaN
# top               M          NaN
# freq           3126          NaN
# mean            NaN    11.683588
# std             NaN     0.587556
# min             NaN     8.543251
# 25%             NaN    11.461632
# 50%             NaN    11.808337
# 75%             NaN    12.072541
# max             NaN    12.624783

# %%
data_1 = data_1.drop('salary_in_usd', axis=1)

# %%
data_dummies = pd.get_dummies(data_1, drop_first=True)

# %%
data_dummies
# Out:
#       work_year  remote_ratio  log_salary  experience_level_EX  \
# 0          2023           100   11.360322                False
# 1          2023           100   10.308953                False
# 2          2023           100   10.146434                False
# 3          2023           100   12.072541                False
# 4          2023           100   11.695247                False
# ...         ...           ...         ...                  ...
# 3749       2021           100   12.013701                False
# 3751       2021           100   11.925035                False
# 3752       2020           100   11.561716                False
# 3753       2020           100   11.512925                False
# 3754       2021            50   11.458100                False
#
#       experience_level_MI  experience_level_SE  employment_type_FL  \
# 0                   False                 True               False
# 1                    True                False               False
# 2                    True                False               False
# 3                   False                 True               False
# 4                   False                 True               False
# ...                   ...                  ...                 ...
# 3749                False                 True               False
# 3751                 True                False               False
# 3752                False                False               False
# 3753                False                False               False
# 3754                False                 True               False
#
#       employment_type_FT  employment_type_PT  job_title_AI Developer  ...  \
# 0                   True               False                   False  ...
# 1                  False               False                   False  ...
# 2                  False               False                   False  ...
# 3                   True               False                   False  ...
# 4                   True               False                   False  ...
# ...                  ...                 ...                     ...  ...
# 3749                True               False                   False  ...
# 3751                True               False                   False  ...
# 3752                True               False                   False  ...
# 3753               False               False                   False  ...
# 3754                True               False                   False  ...
#
#       company_location_SG  company_location_SI  company_location_SK  \
# 0                   False                False                False
# 1                   False                False                False
# 2                   False                False                False
# 3                   False                False                False
# 4                   False                False                False
# ...                   ...                  ...                  ...
# 3749                False                False                False
# 3751                False                False                False
# 3752                False                False                False
# 3753                False                False                False
# 3754                False                False                False
#
#       company_location_TH  company_location_TR  company_location_UA  \
# 0                   False                False                False
# 1                   False                False                False
# 2                   False                False                False
# 3                   False                False                False
# 4                   False                False                False
# ...                   ...                  ...                  ...
# 3749                False                False                False
# 3751                False                False                False
# 3752                False                False                False
# 3753                False                False                False
# 3754                False                False                False
#
#       company_location_US  company_location_VN  company_size_M  company_size_S
# 0                   False                False           False           False
# 1                    True                False           False            True
# 2                    True                False           False            True
# 3                   False                False            True           False
# 4                   False                False            True           False
# ...                   ...                  ...             ...             ...
# 3749                 True                False           False           False
# 3751                 True                False           False           False
# 3752                 True                False           False            True
# 3753                 True                False           False           False
# 3754                False                False           False           False
#
# [3716 rows x 249 columns]

# %%
vif_data = data_dummies.copy()
vif_data = vif_data.astype(float)  # convert all columns to float

from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(vif_data.values, i) for i in range(vif_data.shape[1])]
vif["Features"] = vif_data.columns

# Sort to find most problematic variables
vif.sort_values('VIF', ascending=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:198: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#           VIF                            Features
# 124       inf               employee_residence_EG
# 94        inf    job_title_Product Data Scientist
# 154       inf               employee_residence_NG
# 153       inf               employee_residence_MY
# 152       inf               employee_residence_MX
# ..        ...                                 ...
# 67   2.141541  job_title_Head of Machine Learning
# 87   2.129113        job_title_Power BI Developer
# 89   2.126577  job_title_Principal Data Architect
# 248  2.054014                      company_size_S
# 3    1.780049                 experience_level_EX
#
# [249 rows x 2 columns]

# %%
# 1. Convert all columns to float for VIF
vif_data = data_dummies.astype(float)

# 2. Calculate VIFs
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(vif_data.values, i) for i in range(vif_data.shape[1])]
vif["Features"] = vif_data.columns

# Display full VIF DataFrame without truncation
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Display VIFs sorted by highest
display(vif.sort_values('VIF', ascending=False))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:198: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#              VIF                                           Features
# 124          inf                              employee_residence_EG
# 94           inf                   job_title_Product Data Scientist
# 154          inf                              employee_residence_NG
# 153          inf                              employee_residence_MY
# 152          inf                              employee_residence_MX
# 151          inf                              employee_residence_MT
# 100          inf                              employee_residence_AM
# 101          inf                              employee_residence_AR
# 102          inf                              employee_residence_AS
# 103          inf                              employee_residence_AT
# 104          inf                              employee_residence_AU
# 105          inf                              employee_residence_BA
# 106          inf                              employee_residence_BE
# 107          inf                              employee_residence_BG
# 108          inf                              employee_residence_BO
# 109          inf                              employee_residence_BR
# 110          inf                              employee_residence_CA
# 155          inf                              employee_residence_NL
# 156          inf                              employee_residence_NZ
# 174          inf                              employee_residence_UZ
# 157          inf                              employee_residence_PH
# 172          inf                              employee_residence_UA
# 171          inf                              employee_residence_TR
# 170          inf                              employee_residence_TN
# 169          inf                              employee_residence_TH
# 168          inf                              employee_residence_SK
# 167          inf                              employee_residence_SI
# 166          inf                              employee_residence_SG
# 165          inf                              employee_residence_SE
# 164          inf                              employee_residence_RU
# 163          inf                              employee_residence_RS
# 162          inf                              employee_residence_RO
# 161          inf                              employee_residence_PT
# 160          inf                              employee_residence_PR
# 159          inf                              employee_residence_PL
# 158          inf                              employee_residence_PK
# 111          inf                              employee_residence_CF
# 112          inf                              employee_residence_CH
# 113          inf                              employee_residence_CL
# 114          inf                              employee_residence_CN
# 133          inf                              employee_residence_HR
# 134          inf                              employee_residence_HU
# 135          inf                              employee_residence_ID
# 136          inf                              employee_residence_IE
# 137          inf                              employee_residence_IN
# 138          inf                              employee_residence_IQ
# 139          inf                              employee_residence_IR
# 140          inf                              employee_residence_IT
# 141          inf                              employee_residence_JE
# 142          inf                              employee_residence_JP
# 143          inf                              employee_residence_KE
# 144          inf                              employee_residence_KW
# 145          inf                              employee_residence_LT
# 146          inf                              employee_residence_LU
# 147          inf                              employee_residence_LV
# 132          inf                              employee_residence_HN
# 131          inf                              employee_residence_HK
# 130          inf                              employee_residence_GR
# 121          inf                              employee_residence_DO
# 115          inf                              employee_residence_CO
# 116          inf                              employee_residence_CR
# 117          inf                              employee_residence_CY
# 118          inf                              employee_residence_CZ
# 119          inf                              employee_residence_DE
# 120          inf                              employee_residence_DK
# 122          inf                              employee_residence_DZ
# 129          inf                              employee_residence_GH
# 123          inf                              employee_residence_EE
# 150          inf                              employee_residence_MK
# 125          inf                              employee_residence_ES
# 126          inf                              employee_residence_FI
# 127          inf                              employee_residence_FR
# 128          inf                              employee_residence_GB
# 173          inf                              employee_residence_US
# 175          inf                              employee_residence_VN
# 149          inf                              employee_residence_MD
# 229          inf                                company_location_NL
# 227          inf                                company_location_MY
# 226          inf                                company_location_MX
# 225          inf                                company_location_MT
# 224          inf                                company_location_MK
# 223          inf                                company_location_MD
# 222          inf                                company_location_MA
# 221          inf                                company_location_LV
# 220          inf                                company_location_LU
# 219          inf                                company_location_LT
# 218          inf                                company_location_KE
# 217          inf                                company_location_JP
# 216          inf                                company_location_IT
# 215          inf                                company_location_IR
# 214          inf                                company_location_IQ
# 213          inf                                company_location_IN
# 228          inf                                company_location_NG
# 230          inf                                company_location_NZ
# 176          inf                                company_location_AL
# 231          inf                                company_location_PH
# 246          inf                                company_location_VN
# 245          inf                                company_location_US
# 244          inf                                company_location_UA
# 243          inf                                company_location_TR
# 242          inf                                company_location_TH
# 241          inf                                company_location_SK
# 240          inf                                company_location_SI
# 239          inf                                company_location_SG
# 238          inf                                company_location_SE
# 237          inf                                company_location_RU
# 236          inf                                company_location_RO
# 235          inf                                company_location_PT
# 234          inf                                company_location_PR
# 233          inf                                company_location_PL
# 232          inf                                company_location_PK
# 36           inf                      job_title_Data Analytics Lead
# 212          inf                                company_location_IL
# 211          inf                                company_location_IE
# 210          inf                                company_location_ID
# 191          inf                                company_location_CN
# 190          inf                                company_location_CL
# 189          inf                                company_location_CH
# 188          inf                                company_location_CF
# 187          inf                                company_location_CA
# 186          inf                                company_location_BS
# 185          inf                                company_location_BR
# 184          inf                                company_location_BO
# 183          inf                                company_location_BE
# 182          inf                                company_location_BA
# 181          inf                                company_location_AU
# 180          inf                                company_location_AT
# 179          inf                                company_location_AS
# 178          inf                                company_location_AR
# 177          inf                                company_location_AM
# 192          inf                                company_location_CO
# 193          inf                                company_location_CR
# 194          inf                                company_location_CZ
# 203          inf                                company_location_GB
# 209          inf                                company_location_HU
# 208          inf                                company_location_HR
# 207          inf                                company_location_HN
# 206          inf                                company_location_HK
# 205          inf                                company_location_GR
# 204          inf                                company_location_GH
# 202          inf                                company_location_FR
# 195          inf                                company_location_DE
# 201          inf                                company_location_FI
# 200          inf                                company_location_ES
# 199          inf                                company_location_EG
# 198          inf                                company_location_EE
# 197          inf                                company_location_DZ
# 196          inf                                company_location_DK
# 148          inf                              employee_residence_MA
# 0    7205.322773                                          work_year
# 2    1265.583360                                         log_salary
# 41   1176.032155                            job_title_Data Engineer
# 54    953.904161                           job_title_Data Scientist
# 33    695.045794                             job_title_Data Analyst
# 7     690.726334                                 employment_type_FT
# 76    326.262152                job_title_Machine Learning Engineer
# 12    118.455695                       job_title_Analytics Engineer
# 39    113.895929                           job_title_Data Architect
# 96     91.298567                       job_title_Research Scientist
# 53     67.153838                     job_title_Data Science Manager
# 16     64.000498                        job_title_Applied Scientist
# 95     43.326813                        job_title_Research Engineer
# 73     39.651906                              job_title_ML Engineer
# 45     34.071342                             job_title_Data Manager
# 81     30.823761               job_title_Machine Learning Scientist
# 50     28.480816                  job_title_Data Science Consultant
# 37     26.093085                   job_title_Data Analytics Manager
# 31     20.384493                 job_title_Computer Vision Engineer
# 20     18.283878                          job_title_BI Data Analyst
# 11     18.275923                             job_title_AI Scientist
# 25     18.197493                    job_title_Business Data Analyst
# 56     17.027995                          job_title_Data Specialist
# 22     15.839001                             job_title_BI Developer
# 9      14.214441                             job_title_AI Developer
# 24     14.106807                        job_title_Big Data Engineer
# 15     14.089321       job_title_Applied Machine Learning Scientist
# 77     13.572722  job_title_Machine Learning Infrastructure Engi...
# 5      13.510466                                experience_level_SE
# 61     12.411310                            job_title_ETL Developer
# 48     12.377154                 job_title_Data Operations Engineer
# 65     11.794025                             job_title_Head of Data
# 247    11.736309                                     company_size_M
# 13     11.705136                   job_title_Applied Data Scientist
# 82     11.416138       job_title_Machine Learning Software Engineer
# 60     11.399419                 job_title_Director of Data Science
# 19     11.331062                               job_title_BI Analyst
# 71     11.311841                      job_title_Lead Data Scientist
# 66     10.199909                     job_title_Head of Data Science
# 52     10.130306                        job_title_Data Science Lead
# 75      9.502608               job_title_Machine Learning Developer
# 86      9.152265                             job_title_NLP Engineer
# 91      9.067084                 job_title_Principal Data Scientist
# 49      9.013224                     job_title_Data Quality Analyst
# 70      8.560027                       job_title_Lead Data Engineer
# 35      8.114544                  job_title_Data Analytics Engineer
# 80      7.913631              job_title_Machine Learning Researcher
# 58      7.854638                   job_title_Deep Learning Engineer
# 42      7.844246             job_title_Data Infrastructure Engineer
# 32      7.083078        job_title_Computer Vision Software Engineer
# 93      6.875995                     job_title_Product Data Analyst
# 51      6.774944                    job_title_Data Science Engineer
# 29      6.710741                  job_title_Cloud Database Engineer
# 69      6.654718                        job_title_Lead Data Analyst
# 17      6.467688            job_title_Autonomous Vehicle Technician
# 28      6.252820                      job_title_Cloud Data Engineer
# 98      5.882939                       job_title_Staff Data Analyst
# 97      5.799333                   job_title_Software Data Engineer
# 79      5.568797       job_title_Machine Learning Research Engineer
# 26      5.563256           job_title_Business Intelligence Engineer
# 74      5.559395                           job_title_MLOps Engineer
# 47      5.551780                  job_title_Data Operations Analyst
# 8       5.054239                                 employment_type_PT
# 4       4.605997                                experience_level_MI
# 72      4.440970           job_title_Lead Machine Learning Engineer
# 64      4.437944                   job_title_Financial Data Analyst
# 78      4.427051                 job_title_Machine Learning Manager
# 6       4.367447                                 employment_type_FL
# 84      4.350736                   job_title_Marketing Data Analyst
# 34      4.296059                job_title_Data Analytics Consultant
# 10      4.172551                            job_title_AI Programmer
# 55      3.398428                      job_title_Data Scientist Lead
# 14      3.382585        job_title_Applied Machine Learning Engineer
# 57      3.301453                          job_title_Data Strategist
# 23      3.297113                       job_title_Big Data Architect
# 88      3.295225                   job_title_Principal Data Analyst
# 62      3.291380                             job_title_ETL Engineer
# 90      3.287998                  job_title_Principal Data Engineer
# 68      3.287458                          job_title_Insight Analyst
# 43      3.283822                                job_title_Data Lead
# 46      3.278891                             job_title_Data Modeler
# 38      3.278069                job_title_Data Analytics Specialist
# 85      2.910542                  job_title_Marketing Data Engineer
# 44      2.573576               job_title_Data Management Specialist
# 30      2.413293                  job_title_Compliance Data Analyst
# 99      2.319297                     job_title_Staff Data Scientist
# 18      2.249089                      job_title_Azure Data Engineer
# 40      2.189649                     job_title_Data DevOps Engineer
# 59      2.180715                 job_title_Deep Learning Researcher
# 1       2.155749                                       remote_ratio
# 63      2.154896                     job_title_Finance Data Analyst
# 92      2.150798      job_title_Principal Machine Learning Engineer
# 27      2.150684                     job_title_Cloud Data Architect
# 21      2.150331                         job_title_BI Data Engineer
# 83      2.149077                  job_title_Manager Data Management
# 67      2.141541                 job_title_Head of Machine Learning
# 87      2.129113                       job_title_Power BI Developer
# 89      2.126577                 job_title_Principal Data Architect
# 248     2.054014                                     company_size_S
# 3       1.780049                                experience_level_EX

# %%
data_no_multicollinearity = data_dummies.drop(['work_year'], axis=1)

# %%
targets = data_no_multicollinearity['log_salary']
inputs = data_no_multicollinearity.drop(['log_salary'], axis=1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(inputs)
inputs_scaled = scaler.transform(inputs)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_hat_train = reg.predict(x_train)

plt.scatter(y_train, y_hat_train, alpha=0.3)
plt.xlabel('Actual Log Salary')
plt.ylabel('Predicted Log Salary')
plt.title('Train Set Predictions')
plt.xlim(8, 13)
plt.ylim(8, 13)
plt.show()

# %%
sns.histplot(y_train - y_hat_train, kde=True)
plt.title("Train Residuals")
# Out:
# Text(0.5, 1.0, 'Train Residuals')

# %%
reg.score(x_train, y_train)
# Out:
# 0.6837862630471212

# %%
reg_summary = pd.DataFrame(inputs.columns, columns=['Feature'])
reg_summary['Weight'] = reg.coef_
reg_summary.sort_values('Weight', ascending=False)
# Out:
#                                                Feature        Weight
# 195                                company_location_DZ  7.316735e+12
# 141                              employee_residence_KE  6.279565e+12
# 116                              employee_residence_CZ  6.252722e+12
# 168                              employee_residence_TN  4.421937e+12
# 136                              employee_residence_IQ  4.241574e+12
# 170                              employee_residence_UA  3.539680e+12
# 100                              employee_residence_AS  2.889276e+12
# 222                                company_location_MK  2.750843e+12
# 196                                company_location_EE  2.683844e+12
# 137                              employee_residence_IR  2.479753e+12
# 140                              employee_residence_JP  2.413259e+12
# 96                        job_title_Staff Data Analyst  2.348383e+12
# 171                              employee_residence_US  2.309629e+12
# 221                                company_location_MD  2.235307e+12
# 197                                company_location_EG  2.099774e+12
# 186                                company_location_CF  1.887912e+12
# 154                              employee_residence_NZ  1.843353e+12
# 223                                company_location_MT  1.610456e+12
# 83                   job_title_Marketing Data Engineer  1.594429e+12
# 113                              employee_residence_CO  1.488348e+12
# 237                                company_location_SG  1.452528e+12
# 103                              employee_residence_BA  1.348215e+12
# 126                              employee_residence_GB  1.189353e+12
# 239                                company_location_SK  1.154404e+12
# 98                               employee_residence_AM  1.151676e+12
# 240                                company_location_TH  1.010185e+12
# 108                              employee_residence_CA  8.607265e+11
# 123                              employee_residence_ES  8.356021e+11
# 135                              employee_residence_IN  7.881711e+11
# 132                              employee_residence_HU  7.306064e+11
# 209                                company_location_IE  6.763038e+11
# 205                                company_location_HN  6.685684e+11
# 169                              employee_residence_TR  6.541085e+11
# 117                              employee_residence_DE  6.500965e+11
# 146                              employee_residence_MA  6.101639e+11
# 210                                company_location_IL  5.933916e+11
# 125                              employee_residence_FR  5.792156e+11
# 87                  job_title_Principal Data Architect  5.401820e+11
# 107                              employee_residence_BR  3.997259e+11
# 159                              employee_residence_PT  3.997259e+11
# 128                              employee_residence_GR  3.769671e+11
# 153                              employee_residence_NL  3.650461e+11
# 163                              employee_residence_SE  3.388505e+11
# 217                                company_location_LT  3.211520e+11
# 102                              employee_residence_AU  3.127757e+11
# 145                              employee_residence_LV  3.114758e+11
# 150                              employee_residence_MX  2.982602e+11
# 127                              employee_residence_GH  2.852598e+11
# 138                              employee_residence_IT  2.668440e+11
# 156                              employee_residence_PK  2.668440e+11
# 152                              employee_residence_NG  2.496434e+11
# 157                              employee_residence_PL  2.311560e+11
# 101                              employee_residence_AT  2.311560e+11
# 99                               employee_residence_AR  2.311560e+11
# 104                              employee_residence_BE  2.110440e+11
# 158                              employee_residence_PR  2.110440e+11
# 15             job_title_Autonomous Vehicle Technician  2.019402e+11
# 110                              employee_residence_CH  1.887889e+11
# 162                              employee_residence_RU  1.887889e+11
# 118                              employee_residence_DK  1.635180e+11
# 160                              employee_residence_RO  1.635180e+11
# 106                              employee_residence_BO  1.635180e+11
# 173                              employee_residence_VN  1.635180e+11
# 111                              employee_residence_CL  1.335299e+11
# 172                              employee_residence_UZ  1.335299e+11
# 129                              employee_residence_HK  1.335299e+11
# 155                              employee_residence_PH  1.335299e+11
# 39                             job_title_Data Engineer  1.083611e+11
# 52                            job_title_Data Scientist  1.010581e+11
# 112                              employee_residence_CN  9.443261e+10
# 119                              employee_residence_DO  9.443261e+10
# 144                              employee_residence_LU  9.443261e+10
# 151                              employee_residence_MY  9.443261e+10
# 142                              employee_residence_KW  9.443261e+10
# 114                              employee_residence_CR  9.443261e+10
# 161                              employee_residence_RS  9.443261e+10
# 133                              employee_residence_ID  9.443261e+10
# 31                              job_title_Data Analyst  8.964737e+10
# 74                 job_title_Machine Learning Engineer  6.440279e+10
# 206                                company_location_HR  5.095436e+10
# 10                        job_title_Analytics Engineer  3.973054e+10
# 37                            job_title_Data Architect  3.897299e+10
# 94                        job_title_Research Scientist  3.491058e+10
# 51                      job_title_Data Science Manager  2.999907e+10
# 14                         job_title_Applied Scientist  2.922491e+10
# 93                         job_title_Research Engineer  2.402911e+10
# 71                               job_title_ML Engineer  2.304376e+10
# 139                              employee_residence_JE  2.223156e+10
# 165                              employee_residence_SI  2.220237e+10
# 43                              job_title_Data Manager  2.129646e+10
# 79                job_title_Machine Learning Scientist  2.017306e+10
# 48                   job_title_Data Science Consultant  1.938690e+10
# 35                    job_title_Data Analytics Manager  1.856657e+10
# 29                  job_title_Computer Vision Engineer  1.633197e+10
# 9                               job_title_AI Scientist  1.534536e+10
# 18                           job_title_BI Data Analyst  1.534536e+10
# 23                     job_title_Business Data Analyst  1.534536e+10
# 54                           job_title_Data Specialist  1.482703e+10
# 20                              job_title_BI Developer  1.428961e+10
# 7                               job_title_AI Developer  1.314808e+10
# 75   job_title_Machine Learning Infrastructure Engi...  1.314808e+10
# 22                         job_title_Big Data Engineer  1.314808e+10
# 13        job_title_Applied Machine Learning Scientist  1.314808e+10
# 59                             job_title_ETL Developer  1.253789e+10
# 46                  job_title_Data Operations Engineer  1.253789e+10
# 69                       job_title_Lead Data Scientist  1.189610e+10
# 63                              job_title_Head of Data  1.189610e+10
# 80        job_title_Machine Learning Software Engineer  1.189610e+10
# 58                  job_title_Director of Data Science  1.189610e+10
# 11                    job_title_Applied Data Scientist  1.189610e+10
# 17                                job_title_BI Analyst  1.189610e+10
# 64                      job_title_Head of Data Science  1.121726e+10
# 50                         job_title_Data Science Lead  1.121726e+10
# 89                  job_title_Principal Data Scientist  1.049420e+10
# 84                              job_title_NLP Engineer  1.049420e+10
# 73                job_title_Machine Learning Developer  1.049420e+10
# 47                      job_title_Data Quality Analyst  1.049420e+10
# 68                        job_title_Lead Data Engineer  9.717051e+09
# 40              job_title_Data Infrastructure Engineer  9.717051e+09
# 78               job_title_Machine Learning Researcher  9.717051e+09
# 33                   job_title_Data Analytics Engineer  9.717051e+09
# 56                    job_title_Deep Learning Engineer  9.717051e+09
# 30         job_title_Computer Vision Software Engineer  8.871609e+09
# 27                   job_title_Cloud Database Engineer  8.871609e+09
# 49                     job_title_Data Science Engineer  8.871609e+09
# 67                         job_title_Lead Data Analyst  8.871609e+09
# 91                      job_title_Product Data Analyst  8.871609e+09
# 24            job_title_Business Intelligence Engineer  7.936077e+09
# 72                            job_title_MLOps Engineer  7.936077e+09
# 77        job_title_Machine Learning Research Engineer  7.936077e+09
# 45                   job_title_Data Operations Analyst  7.936077e+09
# 26                       job_title_Cloud Data Engineer  6.873770e+09
# 70            job_title_Lead Machine Learning Engineer  6.873770e+09
# 62                    job_title_Financial Data Analyst  6.873770e+09
# 76                  job_title_Machine Learning Manager  6.873770e+09
# 82                    job_title_Marketing Data Analyst  5.613166e+09
# 41                                 job_title_Data Lead  5.613166e+09
# 88                   job_title_Principal Data Engineer  5.613166e+09
# 53                       job_title_Data Scientist Lead  5.613166e+09
# 86                    job_title_Principal Data Analyst  5.613166e+09
# 95                    job_title_Software Data Engineer  5.613166e+09
# 8                              job_title_AI Programmer  5.613166e+09
# 32                 job_title_Data Analytics Consultant  5.613166e+09
# 44                              job_title_Data Modeler  5.613166e+09
# 60                              job_title_ETL Engineer  5.613166e+09
# 36                 job_title_Data Analytics Specialist  5.613166e+09
# 66                           job_title_Insight Analyst  5.613166e+09
# 65                  job_title_Head of Machine Learning  3.969642e+09
# 25                      job_title_Cloud Data Architect  3.969642e+09
# 57                  job_title_Deep Learning Researcher  3.969642e+09
# 38                      job_title_Data DevOps Engineer  3.969642e+09
# 42                job_title_Data Management Specialist  3.969642e+09
# 61                      job_title_Finance Data Analyst  3.969642e+09
# 28                   job_title_Compliance Data Analyst  3.969642e+09
# 81                   job_title_Manager Data Management  3.969642e+09
# 19                          job_title_BI Data Engineer  3.969642e+09
# 85                        job_title_Power BI Developer  3.969642e+09
# 3                                  experience_level_SE  2.052978e-01
# 2                                  experience_level_MI  1.033623e-01
# 1                                  experience_level_EX  1.003667e-01
# 5                                   employment_type_FT  1.684773e-02
# 245                                     company_size_M -3.276825e-03
# 0                                         remote_ratio -4.766805e-03
# 4                                   employment_type_FL -2.082198e-02
# 6                                   employment_type_PT -4.141134e-02
# 246                                     company_size_S -5.819702e-02
# 238                                company_location_SI -2.220237e+10
# 131                              employee_residence_HR -5.095436e+10
# 191                                company_location_CR -9.046297e+10
# 174                                company_location_AL -9.046297e+10
# 229                                company_location_PH -9.443261e+10
# 204                                company_location_HK -9.443261e+10
# 244                                company_location_VN -9.443261e+10
# 182                                company_location_BO -9.443261e+10
# 189                                company_location_CN -1.116663e+11
# 208                                company_location_ID -1.335299e+11
# 234                                company_location_RO -1.335299e+11
# 188                                company_location_CL -1.568257e+11
# 235                                company_location_RU -1.635180e+11
# 176                                company_location_AR -1.635180e+11
# 199                                company_location_FI -1.635180e+11
# 218                                company_location_LU -1.635180e+11
# 115                              employee_residence_CY -1.694386e+11
# 232                                company_location_PR -1.887889e+11
# 214                                company_location_IT -1.887889e+11
# 181                                company_location_BE -1.887889e+11
# 230                                company_location_PK -1.887889e+11
# 194                                company_location_DK -1.887889e+11
# 226                                company_location_NG -2.110440e+11
# 231                                company_location_PL -2.110440e+11
# 187                                company_location_CH -2.110440e+11
# 178                                company_location_AT -2.311560e+11
# 202                                company_location_GH -2.852598e+11
# 224                                company_location_MX -2.982602e+11
# 219                                company_location_LV -3.114758e+11
# 143                              employee_residence_LT -3.211520e+11
# 236                                company_location_SE -3.388505e+11
# 227                                company_location_NL -3.399313e+11
# 179                                company_location_AU -3.527157e+11
# 203                                company_location_GR -3.527157e+11
# 233                                company_location_PT -3.527157e+11
# 183                                company_location_BR -3.650461e+11
# 200                                company_location_FR -5.481809e+11
# 105                              employee_residence_BG -5.730224e+11
# 207                                company_location_HU -5.966180e+11
# 220                                company_location_MA -6.101639e+11
# 241                                company_location_TR -6.541085e+11
# 130                              employee_residence_HN -6.685684e+11
# 134                              employee_residence_IE -6.763038e+11
# 34                       job_title_Data Analytics Lead -6.838546e+11
# 92                    job_title_Product Data Scientist -6.838546e+11
# 193                                company_location_DE -7.014184e+11
# 211                                company_location_IN -7.136387e+11
# 198                                company_location_ES -8.201230e+11
# 185                                company_location_CA -8.705539e+11
# 225                                company_location_MY -9.128636e+11
# 167                              employee_residence_TH -1.010185e+12
# 97                      job_title_Staff Data Scientist -1.049289e+12
# 175                                company_location_AM -1.151676e+12
# 166                              employee_residence_SK -1.154404e+12
# 201                                company_location_GB -1.206282e+12
# 124                              employee_residence_FI -1.207069e+12
# 21                        job_title_Big Data Architect -1.286632e+12
# 164                              employee_residence_SG -1.326149e+12
# 180                                company_location_BA -1.348215e+12
# 16                       job_title_Azure Data Engineer -1.480814e+12
# 190                                company_location_CO -1.488348e+12
# 149                              employee_residence_MT -1.610456e+12
# 228                                company_location_NZ -1.843353e+12
# 109                              employee_residence_CF -1.887912e+12
# 121                              employee_residence_EE -1.898019e+12
# 122                              employee_residence_EG -2.099774e+12
# 184                                company_location_BS -2.182145e+12
# 215                                company_location_JP -2.234545e+12
# 147                              employee_residence_MD -2.235307e+12
# 243                                company_location_US -2.267070e+12
# 55                           job_title_Data Strategist -2.403811e+12
# 213                                company_location_IR -2.479753e+12
# 148                              employee_residence_MK -2.750843e+12
# 177                                company_location_AS -3.531276e+12
# 242                                company_location_UA -3.539680e+12
# 90       job_title_Principal Machine Learning Engineer -3.993893e+12
# 12         job_title_Applied Machine Learning Engineer -4.011419e+12
# 212                                company_location_IQ -4.241574e+12
# 216                                company_location_KE -6.279565e+12
# 120                              employee_residence_DZ -7.316735e+12
# 192                                company_location_CZ -7.656958e+12

# %%
y_hat_test = reg.predict(x_test)

plt.scatter(y_test, y_hat_test, alpha=0.3)
plt.xlabel('Actual Log Salary')
plt.ylabel('Predicted Log Salary')
plt.title('Test Set Predictions')
plt.xlim(8, 13)
plt.ylim(8, 13)
plt.show()

# %%
df_eval = pd.DataFrame({
    'Prediction': np.exp(y_hat_test),
    'Target': np.exp(y_test.reset_index(drop=True))
})
df_eval['Residual'] = df_eval['Target'] - df_eval['Prediction']
df_eval['Difference%'] = abs(df_eval['Residual'] / df_eval['Target']) * 100
df_eval.describe()
# Out:
# <ipython-input-32-3bd0de2fdaba>:2: RuntimeWarning: overflow encountered in exp
#   'Prediction': np.exp(y_hat_test),
#          Prediction         Target      Residual  Difference%
# count  7.440000e+02     744.000000  7.440000e+02   744.000000
# mean            inf  133102.157258          -inf          inf
# std             NaN   57187.219181           NaN          NaN
# min    0.000000e+00    5409.000000          -inf     0.064316
# 25%    1.098879e+05   93437.500000 -2.410136e+04    11.046403
# 50%    1.483347e+05  130000.000000 -6.837019e+02    21.881342
# 75%    1.540743e+05  170000.000000  3.098667e+04    36.928064
# max             inf  300240.000000  1.900000e+05          inf
